# %%
# http://python-visualization.github.io/folium/
# http://python-visualization.github.io/folium/quickstart.html#Getting-Started
# https://pt-br.topographic-map.com/maps/gn4k/S%C3%A3o-Paulo/

import geopandas as gpd
import folium
import matplotlib.pyplot as plt

# %% [markdown]
# # Roteiro
#
# - PLOT DE MAPA DINÂMICO DA UNICAMP
# - PLOTs DE MAPA DINÂMICO DA UNICAMP com coordenadas do **Dataset RSSI**
# - Gerando TCL file para **ns3::NS2MobilityHelper**

# %% [markdown]
# ### PLOT DE MAPA DINÂMICO DA UNICAMP

# %%
fmap = folium.Map(width= 400,height=400,location=[-22.817050141479882, -47.069764137268066], zoom_start=16, tiles='OpenStreetMap')

# click and open a popup with click region's coords
fmap.add_child(folium.LatLngPopup())
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a7ce91ae620b99e45745828ff2cf091e {
#                     position: relative;
#                     width: 400.0px;
#                     height: 400.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a7ce91ae620b99e45745828ff2cf091e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a7ce91ae620b99e45745828ff2cf091e = L.map(
#                 &quot;map_a7ce91ae620b99e45745828ff2cf091e&quot;,
#                 {
#                     center: [-22.817050141479882, -47.069764137268066],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c7e58de914d55f05fdf7524992cb642e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a7ce91ae620b99e45745828ff2cf091e);
#
#
#                 var lat_lng_popup_2a227d4d54eb3d64ae8fcb6686c93d22 = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_2a227d4d54eb3d64ae8fcb6686c93d22
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.lng.toFixed(4))
#                         .openOn(map_a7ce91ae620b99e45745828ff2cf091e);
#                     }
#                 map_a7ce91ae620b99e45745828ff2cf091e.on(&#x27;click&#x27;, latLngPop);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### PLOTs DE MAPA DINÂMICO DA UNICAMP com coordenadas do Dataset RSSI

# %%
#---- EXTRACT LAT, LNG and RSSI VALUES FROM txt dataset

# The dataset used here is available on: https://github.com/helderbetiol/LoRaWAN-IC2019
def get_txt_values(filename):
    
    # list of all rows of buildings_settings
    file_rows = []

    # open file in a read mode
    file = open(filename, 'r')

    for line in file.readlines():
        
        # create a str without \n and ","
        line_str = line.strip().split("\t")  
        file_rows.append(line_str)
    
    # remove colunm names
    file_rows.pop(0)
    
    return file_rows

txt_rows = get_txt_values('table-rssi-2805')

# %%
# ---- UNICAMP DYNAMIC PLOT MAP & MARKERS OF POSITIONS THAT PACKET WERE RECEIVE

# create folium map
fmap = folium.Map(width= 700,height=700,location=[-22.822617, -47.067], zoom_start=15, tiles='OpenStreetMap')

# add markers
for row in txt_rows:
  lat, lng, rssi = row
  folium.Marker(
      location=[float(lat), float(lng)],
      popup="Lat: " + lat + ", Lng: " + lng + ", RSSI: " + rssi,
      icon=folium.Icon(color="red", icon="info-sign"),
  ).add_to(fmap)

# fmap.add_child(folium.LatLngPopup())

fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec1889f7d05f66fc21f6e48cf900894f {
#                     position: relative;
#                     width: 700.0px;
#                     height: 700.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec1889f7d05f66fc21f6e48cf900894f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ec1889f7d05f66fc21f6e48cf900894f = L.map(
#                 &quot;map_ec1889f7d05f66fc21f6e48cf900894f&quot;,
#                 {
#                     center: [-22.822617, -47.067],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3531fc942c91df2fe2f3a51880976fa6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ec1889f7d05f66fc21f6e48cf900894f);
#
#
#             var marker_1bb03e574ffae8b335dbb2201255aec8 = L.marker(
#                 [-22.814592, -47.057346],
#                 {}
#             ).addTo(map_ec1889f7d05f66fc21f6e48cf900894f);
#
#
#             var icon_bd6837042b2595214ae938f4dadba721 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1bb03e574ffae8b335dbb2201255aec8.setIcon(icon_bd6837042b2595214ae938f4dadba721);
#
#
#         var popup_bc5da76367abce96d1790ed037d013c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_de0bcae766be5c48619fc1ca512b976e = $(`&lt;div id=&quot;html_de0bcae766be5c48619fc1ca512b976e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lat: -22.814592, Lng: -47.057346, RSSI: -95&lt;/div&gt;`)[0];
#             popup_bc5da76367abce96d1790ed037d013c1.setContent(html_de0bcae766be5c48619fc1ca512b976e);
#
#
#         marker_1bb03e574ffae8b335dbb2201255aec8.bindPopup(popup_bc5da76367abce96d1790ed037d013c1)
#         ;
#
#
#
#
#             var marker_ece385951c820d8a1866e61586a40bf4 = L.marker(
#                 [-22.814592, -47.057346],
#                 {}
#             ).addTo(map_ec1889f7d05f66fc21f6e48cf900894f);
#
#
#             var icon_227f6fb6b96c03e67f894128d282f3b6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ece385951c820d8a1866e61586a40bf4.setIcon(icon_227f6fb6b96c03e67f894128d282f3b6);
#
#
#         var popup_ca1f7645fa2d5f2df15d3ceb9df4060a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a9d78de1327a5f1fe3d79433f7f57884 = $(`&lt;div id=&quot;html_a9d78de1327a5f1fe3d79433f7f57884&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lat: -22.814592, Lng: -47.057346, RSSI: -96&lt;/div&gt;`)[0];
#             popup_ca1f7645fa2d5f2df15d3ceb9df4060a.setContent(html_a9d78de1327a5f1fe3d79433f7f57884);
#
#
#         marker_ece385951c820d8a1866e61586a40bf4.bindPopup(popup_ca1f7645fa2d5f2df15d3ceb9df4060a)
#         ;
#
#
#
#
#             var marker_7a1b5f3992644e16972043afed30460f = L.marker(
#                 [-22.81459, -47.057735],
#                 {}
#             ).addTo(map_ec1889f7d05f66fc21f6e48cf900894f);
#
#
#             var icon_6a6af1a55f77d4f783be9e6efeba6fab = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7a1b5f3992644e16972043afed30460f.setIcon(icon_6a6af1a55f77d4f783be9e6efeba6fab);
#
#
#         var popup_faa828ce198357b2ba0a2bcd5576999e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1e78bec8da39db7aac37d004a486cfdc = $(`&lt;div id=&quot;html_1e78bec8da39db7aac37d004a486cfdc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lat: -22.814590, Lng: -47.057735, RSSI: -94&lt;/div&gt;`)[0];
#             popup_faa828ce198357b2ba0a2bcd5576999e.setContent(html_1e78bec8da39db7aac37d004a486cfdc);
#
#
#         marker_7a1b5f3992644e16972043afed30460f.bindPopup(popup_faa828ce198357b2ba0a2bcd5576999e)
#         ;
#
#
#
#
#             var marker_f52515e3b3dc4f993bcc5b42a4dd4a58 = L.marker(
#                 [-22.814543, -47.058243],
#                 {}
#             ).addTo(map_ec1889f7d05f66fc21f6e48cf900894f);
#
#
#             var icon_2d660812e69d40e556e30ac4186a3798 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}

# %%
# ---- UNICAMP DYNAMIC HEATMAP PLOT BASED ON NUMBERS OF MARKERS BY REGIONS
# based on: https://geopandas.org/gallery/plotting_with_folium.html

from folium import plugins

fmap = folium.Map(width= 700,height=700,location=[-22.822617, -47.067], zoom_start=15, tiles='OpenStreetMap')

# lat = row[0] -  lng = row[1]
heat_data = [[row[0],row[1]] for row in txt_rows]

# heat PLOT
# plugins.HeatMap(heat_data).add_to(fmap)
plugins.HeatMap(heat_data, min_opacity=0.25, gradient={.25: 'yellow', .5: 'orange', .75: 'red', 1: 'purple'}).add_to(fmap)
# plugins.HeatMap(heat_data,radius = 25, gradient={.4: 'blue', .65: 'lime', 1: 'red'}).add_to(fmap)
# plugins.HeatMap(heat_data,radius = 25,gradient={'0':'Navy', '0.25':'Blue','0.5':'Green', '0.75':'Yellow','1': 'Red'}).add_to(fmap)

# To DO add a color map bar

# pop up text
fmap.add_child(folium.LatLngPopup())
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_138cbbb8b9899e08f75d4608397d5be5 {
#                     position: relative;
#                     width: 700.0px;
#                     height: 700.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@master/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_138cbbb8b9899e08f75d4608397d5be5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_138cbbb8b9899e08f75d4608397d5be5 = L.map(
#                 &quot;map_138cbbb8b9899e08f75d4608397d5be5&quot;,
#                 {
#                     center: [-22.822617, -47.067],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a71e41a8d2b93721c6c2756055b941c6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_138cbbb8b9899e08f75d4608397d5be5);
#
#
#             var heat_map_9861ef3269109d2ac2a53f0135fa3f8f = L.heatLayer(
#                 [[-22.814592, -47.057346], [-22.814592, -47.057346], [-22.81459, -47.057735], [-22.814543, -47.058243], [-22.814409, -47.058727], [-22.814207, -47.059113], [-22.814207, -47.059113], [-22.814178, -47.059174], [-22.814178, -47.059174], [-22.814177, -47.059174], [-22.814112, -47.059258], [-22.814032, -47.059376], [-22.813692, -47.060658], [-22.813692, -47.060658], [-22.81337, -47.062614], [-22.81337, -47.062614], [-22.81337, -47.062614], [-22.813251, -47.063316], [-22.813251, -47.063316], [-22.813196, -47.064236], [-22.814032, -47.064476], [-22.814198, -47.06435], [-22.815622, -47.063637], [-22.81905, -47.064487], [-22.819963, -47.065346], [-22.820189, -47.065697], [-22.820457, -47.066055], [-22.820593, -47.06625], [-22.821177, -47.067242], [-22.82127, -47.067417], [-22.821287, -47.067451], [-22.821363, -47.067699], [-22.821304, -47.067883], [-22.820816, -47.068146], [-22.820816, -47.068146], [-22.820759, -47.068176], [-22.820759, -47.068176], [-22.820568, -47.068264], [-22.820124, -47.068241], [-22.820124, -47.068241], [-22.819832, -47.067715], [-22.819464, -47.06723], [-22.819258, -47.067078], [-22.819073, -47.066872], [-22.817003